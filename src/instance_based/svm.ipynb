# %%
import os
import sys

path = os.path.join(os.getcwd(), '../')
sys.path.append(path)

# %%
from sklearn.datasets import load_breast_cancer

data = load_breast_cancer()
X, y = data.data, data.target

# %%
from utils import train_test_split, normalize

X = normalize(X)
X_train, y_train, X_test, y_test = train_test_split(X, y)

# %%
from svm import SVM, SoftMarginSVM

svm_model = SVM(X_train, y_train)
W, b = svm_model.fit()
svm_precision = svm_model.test(X_test, y_test)
# Out:
# Accuracy: 93.86%

# %%
softmargin_svm_model = SoftMarginSVM(X_train, y_train, l=0.01)
W, loss_hist = softmargin_svm_model.fit(lr=0.1, nepoches=100, print_every=1, plot=True)
# Out:
# Epoch 1/100	Loss: 0.8430543792362064
# Epoch 2/100	Loss: 0.5756058801889852
# Epoch 3/100	Loss: 0.4779372492980012
# Epoch 4/100	Loss: 0.425520527661416
# Epoch 5/100	Loss: 0.4000862902518392
# Epoch 6/100	Loss: 0.401504898443085
# Epoch 7/100	Loss: 0.36207638443319473
# Epoch 8/100	Loss: 0.3518414817118538
# Epoch 9/100	Loss: 0.34115165958891114
# Epoch 10/100	Loss: 0.3342954878815705
# Epoch 11/100	Loss: 0.3201326617953337
# Epoch 12/100	Loss: 0.32183871837806516
# Epoch 13/100	Loss: 0.3097177611928035
# Epoch 14/100	Loss: 0.3090841755601701
# Epoch 15/100	Loss: 0.30021291276536555
# Epoch 16/100	Loss: 0.2950017478308722
# Epoch 17/100	Loss: 0.30543069697599146
# Epoch 18/100	Loss: 0.291519501494527
# Epoch 19/100	Loss: 0.28660840712032076
# Epoch 20/100	Loss: 0.2911259605839792
# Epoch 21/100	Loss: 0.28301126954621597
# Epoch 22/100	Loss: 0.28022045709543353
# Epoch 23/100	Loss: 0.2784930470350722
# Epoch 24/100	Loss: 0.2772618188443095
# Epoch 25/100	Loss: 0.2786265276916083
# Epoch 26/100	Loss: 0.274415844698083
# Epoch 27/100	Loss: 0.2739376182406399
# Epoch 28/100	Loss: 0.2724758540197939
# Epoch 29/100	Loss: 0.27433742932627075
# Epoch 30/100	Loss: 0.2708560520206528
# Epoch 31/100	Loss: 0.2730434964313646
# Epoch 32/100	Loss: 0.2763044992325541
# Epoch 33/100	Loss: 0.2712327232796514
# Epoch 34/100	Loss: 0.27188081222912525
# Epoch 35/100	Loss: 0.27200614683082114
# Epoch 36/100	Loss: 0.2682386099354141
# Epoch 37/100	Loss: 0.26706774701056757
# Epoch 38/100	Loss: 0.2670313180948493
# Epoch 39/100	Loss: 0.2739742325712382
# Epoch 40/100	Loss: 0.26968926199134124
# Epoch 41/100	Loss: 0.26776723793167495
# Epoch 42/100	Loss: 0.26581416963350324
# Epoch 43/100	Loss: 0.26622246297566765
# Epoch 44/100	Loss: 0.2661746078408832
# Epoch 45/100	Loss: 0.26518159659027885
# Epoch 46/100	Loss: 0.2674923631557909
# Epoch 47/100	Loss: 0.265273208749341
# Epoch 48/100	Loss: 0.2653831227834225
# Epoch 49/100	Loss: 0.26462508889270864
# Epoch 50/100	Loss: 0.26635420953409816
# Epoch 51/100	Loss: 0.26697638598853096
# Epoch 52/100	Loss: 0.26455665244601606
# Epoch 53/100	Loss: 0.2650510976611006
# Epoch 54/100	Loss: 0.27043842382756217
# Epoch 55/100	Loss: 0.26695892209260647
# Epoch 56/100	Loss: 0.26763155714736553
# Epoch 57/100	Loss: 0.26668780542057424
# Epoch 58/100	Loss: 0.2648013106235503
# Epoch 59/100	Loss: 0.2763105946259384
# Epoch 60/100	Loss: 0.2639065873129743
# Epoch 61/100	Loss: 0.2759180867124244
# Epoch 62/100	Loss: 0.2679179098855942
# Epoch 63/100	Loss: 0.263968701404428
# Epoch 64/100	Loss: 0.26476741292419076
# Epoch 65/100	Loss: 0.2691746650731114
# Epoch 66/100	Loss: 0.2641789591583176
# Epoch 67/100	Loss: 0.26459511717141765
# Epoch 68/100	Loss: 0.26778924405177545
# Epoch 69/100	Loss: 0.26390463968078626
# Epoch 70/100	Loss: 0.26466417994266495
# Epoch 71/100	Loss: 0.26491747497699064
# Epoch 72/100	Loss: 0.2812405085495481
# Epoch 73/100	Loss: 0.2637530923221836
# Epoch 74/100	Loss: 0.27717003305891524
# Epoch 75/100	Loss: 0.26892172873481995
# Epoch 76/100	Loss: 0.2635758080563171
# Epoch 77/100	Loss: 0.2706001629917954
# Epoch 78/100	Loss: 0.270498580529416
# Epoch 79/100	Loss: 0.2637674287735769
# Epoch 80/100	Loss: 0.2712192100120044
# Epoch 81/100	Loss: 0.26413362236727267
# Epoch 82/100	Loss: 0.26387481727681855
# Epoch 83/100	Loss: 0.26579892216942347
# Epoch 84/100	Loss: 0.2638414839076515
# Epoch 85/100	Loss: 0.26370511991355194
# Epoch 86/100	Loss: 0.26603664206366384
# Epoch 87/100	Loss: 0.26351446955135516
# Epoch 88/100	Loss: 0.2661217979248918
# Epoch 89/100	Loss: 0.26398625131004066
# Epoch 90/100	Loss: 0.2643047366740451
# Epoch 91/100	Loss: 0.2638049597432674
# Epoch 92/100	Loss: 0.26445603149211017
# Epoch 93/100	Loss: 0.2646262849258037
# Epoch 94/100	Loss: 0.26429824543106206
# Epoch 95/100	Loss: 0.2647921426571664
# Epoch 96/100	Loss: 0.26496219174558594
# Epoch 97/100	Loss: 0.27192949414131806
# Epoch 98/100	Loss: 0.29136172575977803
# Epoch 99/100	Loss: 0.2637939544906532
# Epoch 100/100	Loss: 0.27220669016394505

# %%
softmargin_svm_precision = softmargin_svm_model.test(X_test, y_test)
# Out:
# Accuracy: 96.49%
