# %%
import os
import sys

path = os.path.join(os.getcwd(), '../')
sys.path.append(path)

# %%
from read_data import read_breast_cancer

X_train, y_train, X_test, y_test = read_breast_cancer()

# %%
from logistic_regression import LogisticRegression

logistic_regression_model = LogisticRegression(X_train, y_train)

# %%
W, loss_hist = logistic_regression_model.fit(lr=1.5, nepoches=100, print_every=1, plot=True)
# Out:
# Epoch 1/100	Loss: 0.2946439518950228
# Epoch 2/100	Loss: 0.2039824768096547
# Epoch 3/100	Loss: 0.18055390112671474
# Epoch 4/100	Loss: 0.15496925255313204
# Epoch 5/100	Loss: 0.14165726816189994
# Epoch 6/100	Loss: 0.14110352863382705
# Epoch 7/100	Loss: 0.1245378879906726
# Epoch 8/100	Loss: 0.1197931390831019
# Epoch 9/100	Loss: 0.11587752989087051
# Epoch 10/100	Loss: 0.12080626413527772
# Epoch 11/100	Loss: 0.12140543513816732
# Epoch 12/100	Loss: 0.10186354717490607
# Epoch 13/100	Loss: 0.10028385289261632
# Epoch 14/100	Loss: 0.09700396699287031
# Epoch 15/100	Loss: 0.09450119323555475
# Epoch 16/100	Loss: 0.0924434568109103
# Epoch 17/100	Loss: 0.09105365439142095
# Epoch 18/100	Loss: 0.09155241922735707
# Epoch 19/100	Loss: 0.09768867227310209
# Epoch 20/100	Loss: 0.08617093222983505
# Epoch 21/100	Loss: 0.0920183400977016
# Epoch 22/100	Loss: 0.0845732878467664
# Epoch 23/100	Loss: 0.0891628633319639
# Epoch 24/100	Loss: 0.09463078566238169
# Epoch 25/100	Loss: 0.08534678915057718
# Epoch 26/100	Loss: 0.07974015704257958
# Epoch 27/100	Loss: 0.08581714812373331
# Epoch 28/100	Loss: 0.07799930316834552
# Epoch 29/100	Loss: 0.07718398625547153
# Epoch 30/100	Loss: 0.0826656869329687
# Epoch 31/100	Loss: 0.077737871663253
# Epoch 32/100	Loss: 0.0753314063874339
# Epoch 33/100	Loss: 0.08719505312243572
# Epoch 34/100	Loss: 0.075776623846356
# Epoch 35/100	Loss: 0.07418166338689361
# Epoch 36/100	Loss: 0.07863501461381105
# Epoch 37/100	Loss: 0.07232345883406988
# Epoch 38/100	Loss: 0.07474912092372063
# Epoch 39/100	Loss: 0.07165450371189672
# Epoch 40/100	Loss: 0.07202780261170597
# Epoch 41/100	Loss: 0.07042397573992151
# Epoch 42/100	Loss: 0.07336801255578985
# Epoch 43/100	Loss: 0.06925583844339417
# Epoch 44/100	Loss: 0.06904974592237971
# Epoch 45/100	Loss: 0.06925465913659305
# Epoch 46/100	Loss: 0.0680402124189954
# Epoch 47/100	Loss: 0.06774296688358059
# Epoch 48/100	Loss: 0.0685356057357944
# Epoch 49/100	Loss: 0.0680880947222814
# Epoch 50/100	Loss: 0.06661915524898371
# Epoch 51/100	Loss: 0.06833479288039206
# Epoch 52/100	Loss: 0.06787155433196783
# Epoch 53/100	Loss: 0.06569250076310594
# Epoch 54/100	Loss: 0.06846629540153619
# Epoch 55/100	Loss: 0.06685753537509011
# Epoch 56/100	Loss: 0.06485577095956244
# Epoch 57/100	Loss: 0.06684005149876139
# Epoch 58/100	Loss: 0.0645850018750892
# Epoch 59/100	Loss: 0.06408599649023813
# Epoch 60/100	Loss: 0.06501924884296051
# Epoch 61/100	Loss: 0.06338623763981364
# Epoch 62/100	Loss: 0.06550103644891196
# Epoch 63/100	Loss: 0.06292591050768416
# Epoch 64/100	Loss: 0.06265993584345911
# Epoch 65/100	Loss: 0.06533200188239724
# Epoch 66/100	Loss: 0.06290492989520821
# Epoch 67/100	Loss: 0.06234138274490943
# Epoch 68/100	Loss: 0.0632949581738044
# Epoch 69/100	Loss: 0.06193750374520114
# Epoch 70/100	Loss: 0.06161185658151759
# Epoch 71/100	Loss: 0.06443986361126758
# Epoch 72/100	Loss: 0.06844927240730432
# Epoch 73/100	Loss: 0.06087194644776637
# Epoch 74/100	Loss: 0.06069098440595118
# Epoch 75/100	Loss: 0.06068881706659435
# Epoch 76/100	Loss: 0.06342182957904324
# Epoch 77/100	Loss: 0.0608411008243158
# Epoch 78/100	Loss: 0.0619048782122676
# Epoch 79/100	Loss: 0.05970628900984882
# Epoch 80/100	Loss: 0.0658138713840008
# Epoch 81/100	Loss: 0.06139885297615201
# Epoch 82/100	Loss: 0.060686188570705235
# Epoch 83/100	Loss: 0.059023710640737935
# Epoch 84/100	Loss: 0.05891749768248412
# Epoch 85/100	Loss: 0.058972160671571475
# Epoch 86/100	Loss: 0.05982605949728793
# Epoch 87/100	Loss: 0.058787679018713054
# Epoch 88/100	Loss: 0.05871194091820386
# Epoch 89/100	Loss: 0.05821307113606549
# Epoch 90/100	Loss: 0.059149585332261424
# Epoch 91/100	Loss: 0.05807792318665136
# Epoch 92/100	Loss: 0.058308718355601405
# Epoch 93/100	Loss: 0.05968589394980722
# Epoch 94/100	Loss: 0.061244187439310385
# Epoch 95/100	Loss: 0.0584368457516652
# Epoch 96/100	Loss: 0.07402079678156609
# Epoch 97/100	Loss: 0.061074384954572035
# Epoch 98/100	Loss: 0.058212827475332365
# Epoch 99/100	Loss: 0.05802558052105776
# Epoch 100/100	Loss: 0.05714001739987075

# %%
precision = logistic_regression_model.test(X_test, y_test)
# Out:
# Accuracy: 96.49%
