# %%
import os
import sys

path = os.path.join(os.getcwd(), '../')
sys.path.append(path)

# %%
from read_data import read_mnist

X_train, y_train, X_test, y_test = read_mnist()

# %%
from softmax_regression import SoftmaxRegression

softmax_regression_model = SoftmaxRegression(X_train, y_train)

# %%
W, loss_hist = softmax_regression_model.fit(lr=0.05, nepoches=100, print_every=1, plot=True)
# Out:
# Epoch 1/100	Loss: 0.6842621686112095
# Epoch 2/100	Loss: 0.5470456019544321
# Epoch 3/100	Loss: 0.4672342994831888
# Epoch 4/100	Loss: 0.43442589971500295
# Epoch 5/100	Loss: 0.3992006243543454
# Epoch 6/100	Loss: 0.3777173999747065
# Epoch 7/100	Loss: 0.3663293898907154
# Epoch 8/100	Loss: 0.3497600563149331
# Epoch 9/100	Loss: 0.3356560243891686
# Epoch 10/100	Loss: 0.33357944897357356
# Epoch 11/100	Loss: 0.3217923713938629
# Epoch 12/100	Loss: 0.31185190616405406
# Epoch 13/100	Loss: 0.30785693923356583
# Epoch 14/100	Loss: 0.29973694398151807
# Epoch 15/100	Loss: 0.2952826759782698
# Epoch 16/100	Loss: 0.29237360604448115
# Epoch 17/100	Loss: 0.2943513593834075
# Epoch 18/100	Loss: 0.2820775421311863
# Epoch 19/100	Loss: 0.28226411008421076
# Epoch 20/100	Loss: 0.2808527325311022
# Epoch 21/100	Loss: 0.27568305027688056
# Epoch 22/100	Loss: 0.27240695638326595
# Epoch 23/100	Loss: 0.27145388577688195
# Epoch 24/100	Loss: 0.27046017062634514
# Epoch 25/100	Loss: 0.2721675630932528
# Epoch 26/100	Loss: 0.266932033460124
# Epoch 27/100	Loss: 0.2669041190041436
# Epoch 28/100	Loss: 0.26454549962459667
# Epoch 29/100	Loss: 0.2583904991995814
# Epoch 30/100	Loss: 0.2589718620699277
# Epoch 31/100	Loss: 0.26524117030215094
# Epoch 32/100	Loss: 0.26029020998189994
# Epoch 33/100	Loss: 0.25551846317787874
# Epoch 34/100	Loss: 0.25550351455872117
# Epoch 35/100	Loss: 0.25677758997562844
# Epoch 36/100	Loss: 0.2541785192093655
# Epoch 37/100	Loss: 0.25995762937310996
# Epoch 38/100	Loss: 0.2502525210188456
# Epoch 39/100	Loss: 0.2495340464307763
# Epoch 40/100	Loss: 0.25467221415582875
# Epoch 41/100	Loss: 0.24670841045411654
# Epoch 42/100	Loss: 0.2524290103087218
# Epoch 43/100	Loss: 0.2471509394885439
# Epoch 44/100	Loss: 0.24578737392605118
# Epoch 45/100	Loss: 0.24412868941887808
# Epoch 46/100	Loss: 0.24888920171240805
# Epoch 47/100	Loss: 0.24356148862379867
# Epoch 48/100	Loss: 0.24574040578412373
# Epoch 49/100	Loss: 0.25317934988180046
# Epoch 50/100	Loss: 0.24386617214712195
# Epoch 51/100	Loss: 0.23995439896277077
# Epoch 52/100	Loss: 0.24176164179319773
# Epoch 53/100	Loss: 0.24154601274149812
# Epoch 54/100	Loss: 0.2400497799886927
# Epoch 55/100	Loss: 0.23943381137929876
# Epoch 56/100	Loss: 0.24164291517230443
# Epoch 57/100	Loss: 0.239429014104753
# Epoch 58/100	Loss: 0.2402807588761795
# Epoch 59/100	Loss: 0.23820765476915767
# Epoch 60/100	Loss: 0.2382632722435281
# Epoch 61/100	Loss: 0.2380372853580727
# Epoch 62/100	Loss: 0.234722074166356
# Epoch 63/100	Loss: 0.2375391012467596
# Epoch 64/100	Loss: 0.23971395936658438
# Epoch 65/100	Loss: 0.2405711392029198
# Epoch 66/100	Loss: 0.23811107610066776
# Epoch 67/100	Loss: 0.23595508160478873
# Epoch 68/100	Loss: 0.2345830438078669
# Epoch 69/100	Loss: 0.23862419545441227
# Epoch 70/100	Loss: 0.23365467127662234
# Epoch 71/100	Loss: 0.24087962720381664
# Epoch 72/100	Loss: 0.2353029547096752
# Epoch 73/100	Loss: 0.2331138118520328
# Epoch 74/100	Loss: 0.23399078086574568
# Epoch 75/100	Loss: 0.23335733690700797
# Epoch 76/100	Loss: 0.23782561990185955
# Epoch 77/100	Loss: 0.2357674741664872
# Epoch 78/100	Loss: 0.23011628686294833
# Epoch 79/100	Loss: 0.22943776664674292
# Epoch 80/100	Loss: 0.22879543524586876
# Epoch 81/100	Loss: 0.2345631362479728
# Epoch 82/100	Loss: 0.23391376029997166
# Epoch 83/100	Loss: 0.23261162037901997
# Epoch 84/100	Loss: 0.22927554043767776
# Epoch 85/100	Loss: 0.23005437615205424
# Epoch 86/100	Loss: 0.23481114325314173
# Epoch 87/100	Loss: 0.23158774724607117
# Epoch 88/100	Loss: 0.22891402011044057
# Epoch 89/100	Loss: 0.22863482402673987
# Epoch 90/100	Loss: 0.2309811939093188
# Epoch 91/100	Loss: 0.22949625808717622
# Epoch 92/100	Loss: 0.22860455735780208
# Epoch 93/100	Loss: 0.23162563353828655
# Epoch 94/100	Loss: 0.23384038090110548
# Epoch 95/100	Loss: 0.22682752108789891
# Epoch 96/100	Loss: 0.22765209402237604
# Epoch 97/100	Loss: 0.22952483080246583
# Epoch 98/100	Loss: 0.2254071255435993
# Epoch 99/100	Loss: 0.22886961050711496
# Epoch 100/100	Loss: 0.2309529905126164

# %%
precision = softmax_regression_model.test(X_test, y_test)
# Out:
# Accuracy: 91.42%
